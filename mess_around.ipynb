# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]━━ 1/2 [openpyxl]
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("data/idmap.xlsx")
df
# Out:
#        query  entrezgene                          name symbol  \
# 0     P04217         1.0        alpha-1-B glycoprotein   A1BG
# 1     P01023         2.0         alpha-2-macroglobulin    A2M
# 2     A8K2U0    144568.0  alpha-2-macroglobulin like 1  A2ML1
# 3     Q86V21     65985.0    acetoacetyl-CoA synthetase   AACS
# 4     P22760        13.0     arylacetamide deacetylase  AADAC
# ...      ...         ...                           ...    ...
# 8179  Q7M4L6         NaN                           NaN    NaN
# 8180  Q8IVJ8         NaN                           NaN    NaN
# 8181  Q8IXS6         NaN                           NaN    NaN
# 8182  Q8IZM8         NaN                           NaN    NaN
# 8183  Q96Q06         NaN                           NaN    NaN
#
#                              alias   taxid        HGNC
# 0          A1B, ABG, GAB, HYST2477  9606.0      HGNC:5
# 1     A2MD, CPAMD5, FWP007, S863-7  9606.0      HGNC:7
# ...
